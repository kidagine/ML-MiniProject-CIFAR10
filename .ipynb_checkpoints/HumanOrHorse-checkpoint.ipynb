# %% [markdown]
# ## Horses Or Humans

# %% [markdown]
# # Setup

# %%
# imports
import tensorflow as tf
from tensorflow import keras
import tensorflow_datasets as tfds
import sys
import sklearn
import numpy as np
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# # The Horses Or Humans Dataset
#
# This dataset contains 500 CGI images of horses and 500 CGI images of humans.
#
# Horse (class 0)
# Human (class 1)
#
# We want to train a machine learning model to classify examples as either horse or human based on the images.
# ![title](horses_or_humans.png)

# %% [markdown]
# ## Loading

# %%
(ds_train, ds_test) = tfds.load('horses_or_humans', split=['train', 'test'], as_supervised=True, shuffle_files=True)

# %% [markdown]
# ## Preparing

# %%
for images, labels in ds_train.take(21):  # only take first element of dataset
    plt.imshow(images)
# Out:
# <TakeDataset shapes: ((300, 300, 3), ()), types: (tf.uint8, tf.int64)>

# %% [markdown]
# ## Training

# %% [markdown]
# ## Evaluation
